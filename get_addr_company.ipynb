# %%
import requests
from bs4 import BeautifulSoup
import re
import xlrd
from urllib.parse import quote
import time

file_path = r'./get_addr_companyname.xlsx'
# file_path = file_path.decode('utf-8')

data = xlrd.open_workbook(file_path)

table = data.sheet_by_name('Sheet1')

col_values = table.col_values(8)

for item in col_values:
    
    item_code = quote(item)
    print(item)


    url = "https://www.tianyancha.com/search?key=%s" % item_code
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"}
    res = requests.get(url, headers=headers)
    #print(res.text)
    html = res.text
    soup = BeautifulSoup(html, "lxml")
    a_tag = soup.find('a',{"class":'name'})['href']
    print(a_tag)
    res2 = requests.get(a_tag, headers=headers)
    # print(res2.text)
    soup2 = BeautifulSoup(res2.text, 'lxml')
    try:
        addr  = soup2.find_all('table', {'class': "table -striped-col -border-top-none"})[0].find_all('td', {"colspan":"4"})[0].get_text()
        print(item, addr)
        time.sleep(2)
    except Exception as e:
        print(e)
        print('fail to get addr: ', item)
        continue
# Out:
# 单位详细名称
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-4b2d1ea16483> in <module>()
#      27     html = res.text
#      28     soup = BeautifulSoup(html, "lxml")
# ---> 29     a_tag = soup.find('a',{"class":'name'})['href']
#      30     print(a_tag)
#      31     res2 = requests.get(a_tag, headers=headers)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import requests
from bs4 import BeautifulSoup
import re
import xlrd
from urllib.parse import quote

file_path = r'./get_addr_companyname.xlsx'
# file_path = file_path.decode('utf-8')

data = xlrd.open_workbook(file_path)

table = data.sheet_by_name('Sheet1')

col_values = table.col_values(8)

for item in col_values:
    item = quote(item)
    print(item)


url = "https://www.tianyancha.com/search?key=%E5%B9%B3%E5%AE%89%E9%93%B6%E8%A1%8C"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"}
res = requests.get(url, headers=headers)
#print(res.text)
html = res.text
soup = BeautifulSoup(html, "lxml")
a_tag = soup.find('a',{"class":'name'})['href']
print(a_tag)
res2 = requests.get(a_tag, headers=headers)
# print(res2.text)
soup2 = BeautifulSoup(res2.text, 'lxml')
addr  = soup2.find_all('table', {'class': "table -striped-col -border-top-none"})[0].find_all('td', {"colspan":"4"})[0].get_text()

print(addr)

# %%
import requests
from bs4 import BeautifulSoup
import re
import xlrd
from urllib.parse import quote
import time

file_path = r'./get_addr_companyname.xlsx'
# file_path = file_path.decode('utf-8')

data = xlrd.open_workbook(file_path)

table = data.sheet_by_name('Sheet1')

col_values = table.col_values(8)[1:]

for item in col_values:
    
    item_code = quote(item)
    print(item)


    url = "https://www.tianyancha.com/search?key=%s" % item_code
    proxies = {
        "http":"116.236.98.78:35863",
        "http":"60.173.203.83:33639",
        "http":"115.223.237.220:9000"
    }
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"}
    try:
        res = requests.get(url, headers=headers, proxies=proxies)
        # print(res)
    except Exception as e:
        print(e)
        continue
        
        
        
    # print(res.text)
    html = res.text
    soup = BeautifulSoup(html, "lxml")
    print(soup)
    a_tag = soup.find('a',{"class":'name '})['href']
    print(a_tag)
    res2 = requests.get(a_tag, headers=headers)
    # print(res2.text)
    soup2 = BeautifulSoup(res2.text, 'lxml')
    try:
        addr  = soup2.find_all('table', {'class': "table -striped-col -border-top-none"})[0].find_all('td', {"colspan":"4"})[0].get_text()
        print(item, addr)
        time.sleep(2)
    except Exception as e:
        print(e)
        print('fail to get addr: ', item)
        continue
# Out:
# 百诚财务代理（深圳）有限公司
# <!DOCTYPE html>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import xlrd
from urllib.parse import quote
import time

url = "https://www.qixin.com/search?key=%E6%B7%B1%E5%9C%B3%E5%B8%82%E5%A5%A5%E8%BE%BE%E5%BA%B7%E5%AE%9E%E4%B8%9A%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8&page=1"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36"}
try:
    res = requests.get(url, headers=headers)
    print(res.text)
except Exception as e:
    print(e)
# Out:
# <!DOCTYPE html><html lang="zh-CN"><head><meta charset="utf-8"><meta name="baidu-site-verification" content="QyPoUuVwwf"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="format-detection" content="telephone=no,email=no,address=no"><meta name="viewport" content="width=device-width, initial-scale=1"><link href="/favicon.ico" rel="icon" type="image/x-icon"><title>启信宝-企业注册信息查询|企业工商信息查询|企业信用信息查询平台</title><meta name="description" content="启信宝为您提供全国企业信用信息查询服务,包括企业注册信息查询、企业工商信息查询、企业信用查询、企业信息查询等相关信息查询!还可以深入了解企业相关的法人股东,企业征信,企业对外投资及任职等各种信息!启信宝帮助您及时全面了解企业经营和人员投资状况."><meta name="keywords" content="启信宝,企业注册信息查询,企业工商信息查询,全国企业信用信息查询,企业信用查询,企查查,天眼查,红盾网,征信查询"><link rel="stylesheet" href="//cache.qixin.com/pcweb/common.25c5012d.css"><link rel="stylesheet" href="//cache.qixin.com/pcweb/auth_mobile.25c5012d.css"><script>
#     (function () {
#       var hm = document.createElement("script");
#       hm.src = "//hm.baidu.com/hm.js?52d64b8d3f6d42a2e416d59635df3f71";
# ...
